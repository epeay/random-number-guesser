# %% [markdown]
# <a href="https://colab.research.google.com/github/epeay/random-number-guesser/blob/main/random_number_guesser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %%
import gym
from gym import spaces
import numpy as np
from collections import deque

HIGHER_THAN_X = 1
CHOSEN_X = 70
history_size = 3

class NumberPredictionEnv(gym.Env):
    def __init__(self):
        super(NumberPredictionEnv, self).__init__()
        # Observation space: 10 integers between 0 and 99
        self.observation_space = spaces.Box(low=0, high=99, shape=(history_size,), dtype=np.int32)
        # Action space: Two actions, 0 (<= 70) and 1 (> 70)
        self.action_space = spaces.Discrete(2)
        self.current_number = None
        self.history = deque(maxlen=history_size)

    def reset(self):
      # Initialize the history with random values
      self.history = deque([np.random.randint(0, 100) for _ in range(history_size)], maxlen=history_size)
      self.current_number = self.history[-1]
      return np.array(self.history)

    def step(self, action):
        guess = ""
        if action == 1:
            guess = ">"
        else:
            guess = "<="

        # Determine if the action was correct
        if (action == 1 and self.current_number > CHOSEN_X) or (action == 0 and self.current_number <= CHOSEN_X):
            print(f"CORRECT - Guess: {self.current_number}{guess}{CHOSEN_X}. History: {self.history}")
            reward = 1
        else:
            print(f"WRONG   - Guess: {self.current_number}{guess}{CHOSEN_X}. History: {self.history}")
            reward = -1

        # Generate a new number and update history
        self.current_number = np.random.randint(0, 100)
        self.history.append(self.current_number)
        print(f"History: {self.history}")
        done = False

        return np.array(self.history), reward, done, {}

    def render(self, mode='human'):
        pass  # Rendering is not necessary for this simple task

# Create the custom environment
env = NumberPredictionEnv()

################################################################

import tensorflow as tf
from collections import deque
import random
import os

# Define the model
def build_model(input_shape, action_size):
    model = Sequential([
        Dense(24, input_dim=input_shape, activation='relu'),  # First hidden layer with 24 neurons
        Dense(24, activation='relu'),  # Second hidden layer with 24 neurons
        Dense(action_size, activation='linear')  # Output layer with neurons equal to action size
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')
    return model

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = build_model(state_size, action_size)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            print("Random action")
            return random.randrange(self.action_size)

        print("Predicting action")
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=2)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# Initialize the agent
state_size = history_size  # Since the environment returns 10 integers
action_size = 2  # Two actions: 0 (<= 70) and 1 (> 70)
agent = DQNAgent(state_size, action_size)

################################################################

# Parameters
episodes = 10
steps_per_episode = 50
batch_size = 32


def train(episodes, steps_per_episode, batch_size, state_size):
    # Training loop
    for e in range(episodes):
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        for step in range(steps_per_episode):
            print(f"Episode {e}, Step {step}")
            action = agent.act(state)
            # print(state)
            # print(f"State: {state[0]}, Action: {action}")
            next_state, reward, done, _ = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])
            agent.remember(state, action, reward, next_state, done)
            state = next_state

        # Run replay at the end of each episode
        if len(agent.memory) > batch_size:
            print(f"Agent memory: {len(agent.memory)}")
            agent.replay(batch_size)

train(episodes, steps_per_episode, batch_size, state_size)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Episode 0, Step 0
# Random action
# WRONG   - Guess: 86<=70. History: deque([35, 63, 86], maxlen=3)
# History: deque([63, 86, 7], maxlen=3)
# Episode 0, Step 1
# Random action
# WRONG   - Guess: 7>70. History: deque([63, 86, 7], maxlen=3)
# History: deque([86, 7, 36], maxlen=3)
# Episode 0, Step 2
# Random action
# WRONG   - Guess: 36>70. History: deque([86, 7, 36], maxlen=3)
# History: deque([7, 36, 27], maxlen=3)
# Episode 0, Step 3
# Random action
# CORRECT - Guess: 27<=70. History: deque([7, 36, 27], maxlen=3)
# History: deque([36, 27, 32], maxlen=3)
# Episode 0, Step 4
# Random action
# WRONG   - Guess: 32>70. History: deque([36, 27, 32], maxlen=3)
# History: deque([27, 32, 21], maxlen=3)
# Episode 0, Step 5
# Random action
# CORRECT - Guess: 21<=70. History: deque([27, 32, 21], maxlen=3)
# History: deque([32, 21, 23], maxlen=3)
# Episode 0, Step 6
# Random action
# WRONG   - Guess: 23>70. History: deque([32, 21, 23], maxlen=3)
# History: deque([21, 23, 18], maxlen=3)
# Episode 0, Step 7
# Random action
# WRONG   - Guess: 18>70. History: deque([21, 23, 18], maxlen=3)
# History: deque([23, 18, 66], maxlen=3)
# Episode 0, Step 8
# Random action
# CORRECT - Guess: 66<=70. History: deque([23, 18, 66], maxlen=3)
# History: deque([18, 66, 71], maxlen=3)
# Episode 0, Step 9
# Random action
# WRONG   - Guess: 71<=70. History: deque([18, 66, 71], maxlen=3)
# History: deque([66, 71, 24], maxlen=3)
# Episode 0, Step 10
# Random action
# CORRECT - Guess: 24<=70. History: deque([66, 71, 24], maxlen=3)
# History: deque([71, 24, 22], maxlen=3)
# Episode 0, Step 11
# Random action
# CORRECT - Guess: 22<=70. History: deque([71, 24, 22], maxlen=3)
# History: deque([24, 22, 51], maxlen=3)
# Episode 0, Step 12
# Random action
# WRONG   - Guess: 51>70. History: deque([24, 22, 51], maxlen=3)
# History: deque([22, 51, 0], maxlen=3)
# Episode 0, Step 13
# Random action
# CORRECT - Guess: 0<=70. History: deque([22, 51, 0], maxlen=3)
# History: deque([51, 0, 54], maxlen=3)
# Episode 0, Step 14
# Random action
# WRONG   - Guess: 54>70. History: deque([51, 0, 54], maxlen=3)
# History: deque([0, 54, 15], maxlen=3)
# Episode 0, Step 15
# Random action
# WRONG   - Guess: 15>70. History: deque([0, 54, 15], maxlen=3)
# History: deque([54, 15, 94], maxlen=3)
# Episode 0, Step 16
# Random action
# CORRECT - Guess: 94>70. History: deque([54, 15, 94], maxlen=3)
# History: deque([15, 94, 98], maxlen=3)
# Episode 0, Step 17
# Random action
# CORRECT - Guess: 98>70. History: deque([15, 94, 98], maxlen=3)
# History: deque([94, 98, 16], maxlen=3)
# Episode 0, Step 18
# Random action
# WRONG   - Guess: 16>70. History: deque([94, 98, 16], maxlen=3)
# History: deque([98, 16, 30], maxlen=3)
# Episode 0, Step 19
# Random action
# CORRECT - Guess: 30<=70. History: deque([98, 16, 30], maxlen=3)
# History: deque([16, 30, 93], maxlen=3)
# Episode 0, Step 20
# Random action
# WRONG   - Guess: 93<=70. History: deque([16, 30, 93], maxlen=3)
# History: deque([30, 93, 54], maxlen=3)
# Episode 0, Step 21
# Random action
# WRONG   - Guess: 54>70. History: deque([30, 93, 54], maxlen=3)
# History: deque([93, 54, 15], maxlen=3)
# Episode 0, Step 22
# Random action
# CORRECT - Guess: 15<=70. History: deque([93, 54, 15], maxlen=3)
# History: deque([54, 15, 53], maxlen=3)
# Episode 0, Step 23
# Random action
# WRONG   - Guess: 53>70. History: deque([54, 15, 53], maxlen=3)
# History: deque([15, 53, 45], maxlen=3)
# Episode 0, Step 24
# Random action
# WRONG   - Guess: 45>70. History: deque([15, 53, 45], maxlen=3)
# History: deque([53, 45, 30], maxlen=3)
# Episode 0, Step 25
# Random action
# WRONG   - Guess: 30>70. History: deque([53, 45, 30], maxlen=3)
# History: deque([45, 30, 40], maxlen=3)
# Episode 0, Step 26
# Random action
# CORRECT - Guess: 40<=70. History: deque([45, 30, 40], maxlen=3)
# History: deque([30, 40, 39], maxlen=3)
# Episode 0, Step 27
# Random action
# WRONG   - Guess: 39>70. History: deque([30, 40, 39], maxlen=3)
# History: deque([40, 39, 59], maxlen=3)
# Episode 0, Step 28
# Random action
# WRONG   - Guess: 59>70. History: deque([40, 39, 59], maxlen=3)
# History: deque([39, 59, 91], maxlen=3)
# Episode 0, Step 29
# Random action
# CORRECT - Guess: 91>70. History: deque([39, 59, 91], maxlen=3)
# History: deque([59, 91, 58], maxlen=3)
# Episode 0, Step 30
# Random action
# WRONG   - Guess: 58>70. History: deque([59, 91, 58], maxlen=3)
# History: deque([91, 58, 18], maxlen=3)
# Episode 0, Step 31
# Random action
# WRONG   - Guess: 18>70. History: deque([91, 58, 18], maxlen=3)
# History: deque([58, 18, 68], maxlen=3)
# Episode 0, Step 32
# Random action
# CORRECT - Guess: 68<=70. History: deque([58, 18, 68], maxlen=3)
# History: deque([18, 68, 47], maxlen=3)
# Episode 0, Step 33
# Random action
# WRONG   - Guess: 47>70. History: deque([18, 68, 47], maxlen=3)
# History: deque([68, 47, 99], maxlen=3)
# Episode 0, Step 34
# Random action
# WRONG   - Guess: 99<=70. History: deque([68, 47, 99], maxlen=3)
# History: deque([47, 99, 27], maxlen=3)
# Episode 0, Step 35
# Random action
# WRONG   - Guess: 27>70. History: deque([47, 99, 27], maxlen=3)
# History: deque([99, 27, 77], maxlen=3)
# Episode 0, Step 36
# Random action
# WRONG   - Guess: 77<=70. History: deque([99, 27, 77], maxlen=3)
# History: deque([27, 77, 46], maxlen=3)
# Episode 0, Step 37
# Random action
# CORRECT - Guess: 46<=70. History: deque([27, 77, 46], maxlen=3)
# History: deque([77, 46, 62], maxlen=3)
# Episode 0, Step 38
# Random action
# CORRECT - Guess: 62<=70. History: deque([77, 46, 62], maxlen=3)
# History: deque([46, 62, 89], maxlen=3)
# Episode 0, Step 39
# Random action
# WRONG   - Guess: 89<=70. History: deque([46, 62, 89], maxlen=3)
# History: deque([62, 89, 44], maxlen=3)
# Episode 0, Step 40
# Random action
# CORRECT - Guess: 44<=70. History: deque([62, 89, 44], maxlen=3)
# History: deque([89, 44, 99], maxlen=3)
# Episode 0, Step 41
# Random action
# WRONG   - Guess: 99<=70. History: deque([89, 44, 99], maxlen=3)
# History: deque([44, 99, 0], maxlen=3)
# Episode 0, Step 42
# Random action
# WRONG   - Guess: 0>70. History: deque([44, 99, 0], maxlen=3)
# History: deque([99, 0, 93], maxlen=3)
# Episode 0, Step 43
# Random action
# CORRECT - Guess: 93>70. History: deque([99, 0, 93], maxlen=3)
# History: deque([0, 93, 68], maxlen=3)
# Episode 0, Step 44
# Random action
# CORRECT - Guess: 68<=70. History: deque([0, 93, 68], maxlen=3)
# History: deque([93, 68, 69], maxlen=3)
# Episode 0, Step 45
# Random action
# WRONG   - Guess: 69>70. History: deque([93, 68, 69], maxlen=3)
# History: deque([68, 69, 80], maxlen=3)
# Episode 0, Step 46
# Random action
# WRONG   - Guess: 80<=70. History: deque([68, 69, 80], maxlen=3)
# History: deque([69, 80, 26], maxlen=3)
# Episode 0, Step 47
# Random action
# CORRECT - Guess: 26<=70. History: deque([69, 80, 26], maxlen=3)
# History: deque([80, 26, 3], maxlen=3)
# Episode 0, Step 48
# Random action
# CORRECT - Guess: 3<=70. History: deque([80, 26, 3], maxlen=3)
# History: deque([26, 3, 26], maxlen=3)
# Episode 0, Step 49
# Random action
# WRONG   - Guess: 26>70. History: deque([26, 3, 26], maxlen=3)
# History: deque([3, 26, 50], maxlen=3)
# Agent memory: 50
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 1s - loss: 81.7529 - 643ms/epoch - 643ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 191.8161 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 65.7372 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 3.0033 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 140.7979 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 258.5809 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 339.5317 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 - 0s - loss: 1.1531 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 1.2402 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 - 0s - loss: 1.7598 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 - 0s - loss: 202.9711 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 196.5054 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 - 0s - loss: 13.7762 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 - 0s - loss: 79.0474 - 10ms/epoch - 10ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 54.0159 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 - 0s - loss: 0.9194 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 - 0s - loss: 33.4091 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 153.8569 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 512.8456 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 17.6232 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 19.6233 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 405.5359 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 2.7646 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 8.2462 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 3.1003 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 0.1449 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 1.7589 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 105.1173 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 8.4385 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 7.9208 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 137.4766 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 15.8323 - 3ms/epoch - 3ms/step
# Episode 1, Step 0
# Random action
# CORRECT - Guess: 2<=70. History: deque([61, 11, 2], maxlen=3)
# History: deque([11, 2, 28], maxlen=3)
# Episode 1, Step 1
# Random action
# WRONG   - Guess: 28>70. History: deque([11, 2, 28], maxlen=3)
# History: deque([2, 28, 5], maxlen=3)
# Episode 1, Step 2
# Random action
# CORRECT - Guess: 5<=70. History: deque([2, 28, 5], maxlen=3)
# History: deque([28, 5, 72], maxlen=3)
# Episode 1, Step 3
# Random action
# CORRECT - Guess: 72>70. History: deque([28, 5, 72], maxlen=3)
# History: deque([5, 72, 47], maxlen=3)
# Episode 1, Step 4
# Random action
# CORRECT - Guess: 47<=70. History: deque([5, 72, 47], maxlen=3)
# History: deque([72, 47, 87], maxlen=3)
# Episode 1, Step 5
# Random action
# CORRECT - Guess: 87>70. History: deque([72, 47, 87], maxlen=3)
# History: deque([47, 87, 27], maxlen=3)
# Episode 1, Step 6
# Random action
# WRONG   - Guess: 27>70. History: deque([47, 87, 27], maxlen=3)
# History: deque([87, 27, 73], maxlen=3)
# Episode 1, Step 7
# Random action
# CORRECT - Guess: 73>70. History: deque([87, 27, 73], maxlen=3)
# History: deque([27, 73, 6], maxlen=3)
# Episode 1, Step 8
# Random action
# CORRECT - Guess: 6<=70. History: deque([27, 73, 6], maxlen=3)
# History: deque([73, 6, 31], maxlen=3)
# Episode 1, Step 9
# Random action
# WRONG   - Guess: 31>70. History: deque([73, 6, 31], maxlen=3)
# History: deque([6, 31, 75], maxlen=3)
# Episode 1, Step 10
# Random action
# WRONG   - Guess: 75<=70. History: deque([6, 31, 75], maxlen=3)
# History: deque([31, 75, 88], maxlen=3)
# Episode 1, Step 11
# Random action
# CORRECT - Guess: 88>70. History: deque([31, 75, 88], maxlen=3)
# History: deque([75, 88, 11], maxlen=3)
# Episode 1, Step 12
# Random action
# CORRECT - Guess: 11<=70. History: deque([75, 88, 11], maxlen=3)
# History: deque([88, 11, 70], maxlen=3)
# Episode 1, Step 13
# Random action
# WRONG   - Guess: 70>70. History: deque([88, 11, 70], maxlen=3)
# History: deque([11, 70, 5], maxlen=3)
# Episode 1, Step 14
# Random action
# CORRECT - Guess: 5<=70. History: deque([11, 70, 5], maxlen=3)
# History: deque([70, 5, 28], maxlen=3)
# Episode 1, Step 15
# Random action
# CORRECT - Guess: 28<=70. History: deque([70, 5, 28], maxlen=3)
# History: deque([5, 28, 1], maxlen=3)
# Episode 1, Step 16
# Random action
# WRONG   - Guess: 1>70. History: deque([5, 28, 1], maxlen=3)
# History: deque([28, 1, 75], maxlen=3)
# Episode 1, Step 17
# Random action
# CORRECT - Guess: 75>70. History: deque([28, 1, 75], maxlen=3)
# History: deque([1, 75, 62], maxlen=3)
# Episode 1, Step 18
# Random action
# CORRECT - Guess: 62<=70. History: deque([1, 75, 62], maxlen=3)
# History: deque([75, 62, 93], maxlen=3)
# Episode 1, Step 19
# Random action
# CORRECT - Guess: 93>70. History: deque([75, 62, 93], maxlen=3)
# History: deque([62, 93, 63], maxlen=3)
# Episode 1, Step 20
# Random action
# CORRECT - Guess: 63<=70. History: deque([62, 93, 63], maxlen=3)
# History: deque([93, 63, 12], maxlen=3)
# Episode 1, Step 21
# Random action
# CORRECT - Guess: 12<=70. History: deque([93, 63, 12], maxlen=3)
# History: deque([63, 12, 89], maxlen=3)
# Episode 1, Step 22
# Random action
# CORRECT - Guess: 89>70. History: deque([63, 12, 89], maxlen=3)
# History: deque([12, 89, 11], maxlen=3)
# Episode 1, Step 23
# Random action
# CORRECT - Guess: 11<=70. History: deque([12, 89, 11], maxlen=3)
# History: deque([89, 11, 6], maxlen=3)
# Episode 1, Step 24
# Random action
# CORRECT - Guess: 6<=70. History: deque([89, 11, 6], maxlen=3)
# History: deque([11, 6, 72], maxlen=3)
# Episode 1, Step 25
# Random action
# WRONG   - Guess: 72<=70. History: deque([11, 6, 72], maxlen=3)
# History: deque([6, 72, 31], maxlen=3)
# Episode 1, Step 26
# Random action
# WRONG   - Guess: 31>70. History: deque([6, 72, 31], maxlen=3)
# History: deque([72, 31, 31], maxlen=3)
# Episode 1, Step 27
# Random action
# CORRECT - Guess: 31<=70. History: deque([72, 31, 31], maxlen=3)
# History: deque([31, 31, 31], maxlen=3)
# Episode 1, Step 28
# Random action
# CORRECT - Guess: 31<=70. History: deque([31, 31, 31], maxlen=3)
# History: deque([31, 31, 45], maxlen=3)
# Episode 1, Step 29
# Random action
# CORRECT - Guess: 45<=70. History: deque([31, 31, 45], maxlen=3)
# History: deque([31, 45, 9], maxlen=3)
# Episode 1, Step 30
# Random action
# CORRECT - Guess: 9<=70. History: deque([31, 45, 9], maxlen=3)
# History: deque([45, 9, 95], maxlen=3)
# Episode 1, Step 31
# Random action
# WRONG   - Guess: 95<=70. History: deque([45, 9, 95], maxlen=3)
# History: deque([9, 95, 24], maxlen=3)
# Episode 1, Step 32
# Random action
# CORRECT - Guess: 24<=70. History: deque([9, 95, 24], maxlen=3)
# History: deque([95, 24, 62], maxlen=3)
# Episode 1, Step 33
# Random action
# WRONG   - Guess: 62>70. History: deque([95, 24, 62], maxlen=3)
# History: deque([24, 62, 82], maxlen=3)
# Episode 1, Step 34
# Random action
# WRONG   - Guess: 82<=70. History: deque([24, 62, 82], maxlen=3)
# History: deque([62, 82, 41], maxlen=3)
# Episode 1, Step 35
# Random action
# WRONG   - Guess: 41>70. History: deque([62, 82, 41], maxlen=3)
# History: deque([82, 41, 15], maxlen=3)
# Episode 1, Step 36
# Random action
# WRONG   - Guess: 15>70. History: deque([82, 41, 15], maxlen=3)
# History: deque([41, 15, 15], maxlen=3)
# Episode 1, Step 37
# Random action
# CORRECT - Guess: 15<=70. History: deque([41, 15, 15], maxlen=3)
# History: deque([15, 15, 12], maxlen=3)
# Episode 1, Step 38
# Random action
# CORRECT - Guess: 12<=70. History: deque([15, 15, 12], maxlen=3)
# History: deque([15, 12, 32], maxlen=3)
# Episode 1, Step 39
# Random action
# WRONG   - Guess: 32>70. History: deque([15, 12, 32], maxlen=3)
# History: deque([12, 32, 98], maxlen=3)
# Episode 1, Step 40
# Random action
# WRONG   - Guess: 98<=70. History: deque([12, 32, 98], maxlen=3)
# History: deque([32, 98, 56], maxlen=3)
# Episode 1, Step 41
# Random action
# CORRECT - Guess: 56<=70. History: deque([32, 98, 56], maxlen=3)
# History: deque([98, 56, 57], maxlen=3)
# Episode 1, Step 42
# Random action
# WRONG   - Guess: 57>70. History: deque([98, 56, 57], maxlen=3)
# History: deque([56, 57, 88], maxlen=3)
# Episode 1, Step 43
# Random action
# CORRECT - Guess: 88>70. History: deque([56, 57, 88], maxlen=3)
# History: deque([57, 88, 22], maxlen=3)
# Episode 1, Step 44
# Random action
# WRONG   - Guess: 22>70. History: deque([57, 88, 22], maxlen=3)
# History: deque([88, 22, 53], maxlen=3)
# Episode 1, Step 45
# Random action
# WRONG   - Guess: 53>70. History: deque([88, 22, 53], maxlen=3)
# History: deque([22, 53, 21], maxlen=3)
# Episode 1, Step 46
# Random action
# CORRECT - Guess: 21<=70. History: deque([22, 53, 21], maxlen=3)
# History: deque([53, 21, 39], maxlen=3)
# Episode 1, Step 47
# Random action
# WRONG   - Guess: 39>70. History: deque([53, 21, 39], maxlen=3)
# History: deque([21, 39, 17], maxlen=3)
# Episode 1, Step 48
# Random action
# CORRECT - Guess: 17<=70. History: deque([21, 39, 17], maxlen=3)
# History: deque([39, 17, 40], maxlen=3)
# Episode 1, Step 49
# Random action
# WRONG   - Guess: 40>70. History: deque([39, 17, 40], maxlen=3)
# History: deque([17, 40, 74], maxlen=3)
# Agent memory: 100
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.0132 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 31.1148 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 44.1610 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 44.0766 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 19.4572 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 5.2414 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 - 0s - loss: 36.7889 - 7ms/epoch - 7ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 1.8497 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 8.0932 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 8.4136 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 9.6128 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 111.3673 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 - 0s - loss: 85.7126 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 10.6756 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 3.4424 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 10.5774 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 61.0804 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 21.0812 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 90.0837 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 16.2919 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 26.4455 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 2.3031 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 4.8878 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 1.1471 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 0.5543 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 6.5104 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 1.9008 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 0.6999 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 4.9584 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 - 0s - loss: 2.9258 - 11ms/epoch - 11ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 - 0s - loss: 249.6768 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 - 0s - loss: 16.6693 - 5ms/epoch - 5ms/step
# Episode 2, Step 0
# Random action
# CORRECT - Guess: 30<=70. History: deque([3, 90, 30], maxlen=3)
# History: deque([90, 30, 75], maxlen=3)
# Episode 2, Step 1
# Random action
# WRONG   - Guess: 75<=70. History: deque([90, 30, 75], maxlen=3)
# History: deque([30, 75, 27], maxlen=3)
# Episode 2, Step 2
# Random action
# CORRECT - Guess: 27<=70. History: deque([30, 75, 27], maxlen=3)
# History: deque([75, 27, 36], maxlen=3)
# Episode 2, Step 3
# Random action
# CORRECT - Guess: 36<=70. History: deque([75, 27, 36], maxlen=3)
# History: deque([27, 36, 30], maxlen=3)
# Episode 2, Step 4
# Random action
# WRONG   - Guess: 30>70. History: deque([27, 36, 30], maxlen=3)
# History: deque([36, 30, 55], maxlen=3)
# Episode 2, Step 5
# Random action
# CORRECT - Guess: 55<=70. History: deque([36, 30, 55], maxlen=3)
# History: deque([30, 55, 35], maxlen=3)
# Episode 2, Step 6
# Random action
# CORRECT - Guess: 35<=70. History: deque([30, 55, 35], maxlen=3)
# History: deque([55, 35, 32], maxlen=3)
# Episode 2, Step 7
# Random action
# CORRECT - Guess: 32<=70. History: deque([55, 35, 32], maxlen=3)
# History: deque([35, 32, 14], maxlen=3)
# Episode 2, Step 8
# Random action
# CORRECT - Guess: 14<=70. History: deque([35, 32, 14], maxlen=3)
# History: deque([32, 14, 65], maxlen=3)
# Episode 2, Step 9
# Random action
# CORRECT - Guess: 65<=70. History: deque([32, 14, 65], maxlen=3)
# History: deque([14, 65, 86], maxlen=3)
# Episode 2, Step 10
# Random action
# WRONG   - Guess: 86<=70. History: deque([14, 65, 86], maxlen=3)
# History: deque([65, 86, 32], maxlen=3)
# Episode 2, Step 11
# Random action
# WRONG   - Guess: 32>70. History: deque([65, 86, 32], maxlen=3)
# History: deque([86, 32, 5], maxlen=3)
# Episode 2, Step 12
# Random action
# CORRECT - Guess: 5<=70. History: deque([86, 32, 5], maxlen=3)
# History: deque([32, 5, 14], maxlen=3)
# Episode 2, Step 13
# Random action
# CORRECT - Guess: 14<=70. History: deque([32, 5, 14], maxlen=3)
# History: deque([5, 14, 10], maxlen=3)
# Episode 2, Step 14
# Random action
# WRONG   - Guess: 10>70. History: deque([5, 14, 10], maxlen=3)
# History: deque([14, 10, 89], maxlen=3)
# Episode 2, Step 15
# Random action
# CORRECT - Guess: 89>70. History: deque([14, 10, 89], maxlen=3)
# History: deque([10, 89, 3], maxlen=3)
# Episode 2, Step 16
# Random action
# CORRECT - Guess: 3<=70. History: deque([10, 89, 3], maxlen=3)
# History: deque([89, 3, 59], maxlen=3)
# Episode 2, Step 17
# Random action
# CORRECT - Guess: 59<=70. History: deque([89, 3, 59], maxlen=3)
# History: deque([3, 59, 6], maxlen=3)
# Episode 2, Step 18
# Random action
# WRONG   - Guess: 6>70. History: deque([3, 59, 6], maxlen=3)
# History: deque([59, 6, 92], maxlen=3)
# Episode 2, Step 19
# Random action
# CORRECT - Guess: 92>70. History: deque([59, 6, 92], maxlen=3)
# History: deque([6, 92, 46], maxlen=3)
# Episode 2, Step 20
# Random action
# CORRECT - Guess: 46<=70. History: deque([6, 92, 46], maxlen=3)
# History: deque([92, 46, 28], maxlen=3)
# Episode 2, Step 21
# Random action
# CORRECT - Guess: 28<=70. History: deque([92, 46, 28], maxlen=3)
# History: deque([46, 28, 0], maxlen=3)
# Episode 2, Step 22
# Random action
# CORRECT - Guess: 0<=70. History: deque([46, 28, 0], maxlen=3)
# History: deque([28, 0, 9], maxlen=3)
# Episode 2, Step 23
# Random action
# WRONG   - Guess: 9>70. History: deque([28, 0, 9], maxlen=3)
# History: deque([0, 9, 79], maxlen=3)
# Episode 2, Step 24
# Random action
# CORRECT - Guess: 79>70. History: deque([0, 9, 79], maxlen=3)
# History: deque([9, 79, 93], maxlen=3)
# Episode 2, Step 25
# Random action
# CORRECT - Guess: 93>70. History: deque([9, 79, 93], maxlen=3)
# History: deque([79, 93, 21], maxlen=3)
# Episode 2, Step 26
# Random action
# CORRECT - Guess: 21<=70. History: deque([79, 93, 21], maxlen=3)
# History: deque([93, 21, 68], maxlen=3)
# Episode 2, Step 27
# Random action
# WRONG   - Guess: 68>70. History: deque([93, 21, 68], maxlen=3)
# History: deque([21, 68, 58], maxlen=3)
# Episode 2, Step 28
# Random action
# WRONG   - Guess: 58>70. History: deque([21, 68, 58], maxlen=3)
# History: deque([68, 58, 32], maxlen=3)
# Episode 2, Step 29
# Random action
# WRONG   - Guess: 32>70. History: deque([68, 58, 32], maxlen=3)
# History: deque([58, 32, 54], maxlen=3)
# Episode 2, Step 30
# Random action
# WRONG   - Guess: 54>70. History: deque([58, 32, 54], maxlen=3)
# History: deque([32, 54, 27], maxlen=3)
# Episode 2, Step 31
# Random action
# WRONG   - Guess: 27>70. History: deque([32, 54, 27], maxlen=3)
# History: deque([54, 27, 99], maxlen=3)
# Episode 2, Step 32
# Random action
# CORRECT - Guess: 99>70. History: deque([54, 27, 99], maxlen=3)
# History: deque([27, 99, 61], maxlen=3)
# Episode 2, Step 33
# Random action
# CORRECT - Guess: 61<=70. History: deque([27, 99, 61], maxlen=3)
# History: deque([99, 61, 88], maxlen=3)
# Episode 2, Step 34
# Random action
# WRONG   - Guess: 88<=70. History: deque([99, 61, 88], maxlen=3)
# History: deque([61, 88, 31], maxlen=3)
# Episode 2, Step 35
# Random action
# WRONG   - Guess: 31>70. History: deque([61, 88, 31], maxlen=3)
# History: deque([88, 31, 7], maxlen=3)
# Episode 2, Step 36
# Random action
# WRONG   - Guess: 7>70. History: deque([88, 31, 7], maxlen=3)
# History: deque([31, 7, 54], maxlen=3)
# Episode 2, Step 37
# Random action
# CORRECT - Guess: 54<=70. History: deque([31, 7, 54], maxlen=3)
# History: deque([7, 54, 5], maxlen=3)
# Episode 2, Step 38
# Random action
# CORRECT - Guess: 5<=70. History: deque([7, 54, 5], maxlen=3)
# History: deque([54, 5, 40], maxlen=3)
# Episode 2, Step 39
# Random action
# WRONG   - Guess: 40>70. History: deque([54, 5, 40], maxlen=3)
# History: deque([5, 40, 17], maxlen=3)
# Episode 2, Step 40
# Random action
# CORRECT - Guess: 17<=70. History: deque([5, 40, 17], maxlen=3)
# History: deque([40, 17, 61], maxlen=3)
# Episode 2, Step 41
# Random action
# WRONG   - Guess: 61>70. History: deque([40, 17, 61], maxlen=3)
# History: deque([17, 61, 91], maxlen=3)
# Episode 2, Step 42
# Random action
# WRONG   - Guess: 91<=70. History: deque([17, 61, 91], maxlen=3)
# History: deque([61, 91, 0], maxlen=3)
# Episode 2, Step 43
# Random action
# WRONG   - Guess: 0>70. History: deque([61, 91, 0], maxlen=3)
# History: deque([91, 0, 84], maxlen=3)
# Episode 2, Step 44
# Random action
# WRONG   - Guess: 84<=70. History: deque([91, 0, 84], maxlen=3)
# History: deque([0, 84, 51], maxlen=3)
# Episode 2, Step 45
# Random action
# WRONG   - Guess: 51>70. History: deque([0, 84, 51], maxlen=3)
# History: deque([84, 51, 65], maxlen=3)
# Episode 2, Step 46
# Random action
# CORRECT - Guess: 65<=70. History: deque([84, 51, 65], maxlen=3)
# History: deque([51, 65, 49], maxlen=3)
# Episode 2, Step 47
# Random action
# WRONG   - Guess: 49>70. History: deque([51, 65, 49], maxlen=3)
# History: deque([65, 49, 92], maxlen=3)
# Episode 2, Step 48
# Random action
# WRONG   - Guess: 92<=70. History: deque([65, 49, 92], maxlen=3)
# History: deque([49, 92, 91], maxlen=3)
# Episode 2, Step 49
# Random action
# CORRECT - Guess: 91>70. History: deque([49, 92, 91], maxlen=3)
# History: deque([92, 91, 55], maxlen=3)
# Agent memory: 150
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 37.4249 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 - 0s - loss: 0.3260 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 - 0s - loss: 8.4599 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 - 0s - loss: 6.6625 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 - 0s - loss: 0.2342 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 - 0s - loss: 45.9319 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 11.9450 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 0.4155 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 27.6242 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 6.8443 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 6.1434 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 131.8524 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 24.3297 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 85.2418 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 64.3197 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 0.3865 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 2.1140 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 9.5209 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 34.4622 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 1.2198 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 1.8925 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 0.2627 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 21.8179 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.7883 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 22.3426 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 4.3214 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 16.2870 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 78.9613 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 - 0s - loss: 1.0732 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 55.7675 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 3.0644 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 14.5811 - 3ms/epoch - 3ms/step
# Episode 3, Step 0
# Random action
# CORRECT - Guess: 89>70. History: deque([38, 42, 89], maxlen=3)
# History: deque([42, 89, 76], maxlen=3)
# Episode 3, Step 1
# Random action
# WRONG   - Guess: 76<=70. History: deque([42, 89, 76], maxlen=3)
# History: deque([89, 76, 61], maxlen=3)
# Episode 3, Step 2
# Random action
# WRONG   - Guess: 61>70. History: deque([89, 76, 61], maxlen=3)
# History: deque([76, 61, 6], maxlen=3)
# Episode 3, Step 3
# Random action
# WRONG   - Guess: 6>70. History: deque([76, 61, 6], maxlen=3)
# History: deque([61, 6, 48], maxlen=3)
# Episode 3, Step 4
# Random action
# CORRECT - Guess: 48<=70. History: deque([61, 6, 48], maxlen=3)
# History: deque([6, 48, 25], maxlen=3)
# Episode 3, Step 5
# Random action
# CORRECT - Guess: 25<=70. History: deque([6, 48, 25], maxlen=3)
# History: deque([48, 25, 5], maxlen=3)
# Episode 3, Step 6
# Random action
# WRONG   - Guess: 5>70. History: deque([48, 25, 5], maxlen=3)
# History: deque([25, 5, 35], maxlen=3)
# Episode 3, Step 7
# Random action
# CORRECT - Guess: 35<=70. History: deque([25, 5, 35], maxlen=3)
# History: deque([5, 35, 50], maxlen=3)
# Episode 3, Step 8
# Random action
# WRONG   - Guess: 50>70. History: deque([5, 35, 50], maxlen=3)
# History: deque([35, 50, 41], maxlen=3)
# Episode 3, Step 9
# Random action
# CORRECT - Guess: 41<=70. History: deque([35, 50, 41], maxlen=3)
# History: deque([50, 41, 33], maxlen=3)
# Episode 3, Step 10
# Random action
# CORRECT - Guess: 33<=70. History: deque([50, 41, 33], maxlen=3)
# History: deque([41, 33, 4], maxlen=3)
# Episode 3, Step 11
# Random action
# CORRECT - Guess: 4<=70. History: deque([41, 33, 4], maxlen=3)
# History: deque([33, 4, 33], maxlen=3)
# Episode 3, Step 12
# Random action
# CORRECT - Guess: 33<=70. History: deque([33, 4, 33], maxlen=3)
# History: deque([4, 33, 68], maxlen=3)
# Episode 3, Step 13
# Random action
# WRONG   - Guess: 68>70. History: deque([4, 33, 68], maxlen=3)
# History: deque([33, 68, 63], maxlen=3)
# Episode 3, Step 14
# Random action
# WRONG   - Guess: 63>70. History: deque([33, 68, 63], maxlen=3)
# History: deque([68, 63, 2], maxlen=3)
# Episode 3, Step 15
# Random action
# CORRECT - Guess: 2<=70. History: deque([68, 63, 2], maxlen=3)
# History: deque([63, 2, 4], maxlen=3)
# Episode 3, Step 16
# Random action
# WRONG   - Guess: 4>70. History: deque([63, 2, 4], maxlen=3)
# History: deque([2, 4, 11], maxlen=3)
# Episode 3, Step 17
# Random action
# CORRECT - Guess: 11<=70. History: deque([2, 4, 11], maxlen=3)
# History: deque([4, 11, 86], maxlen=3)
# Episode 3, Step 18
# Random action
# CORRECT - Guess: 86>70. History: deque([4, 11, 86], maxlen=3)
# History: deque([11, 86, 3], maxlen=3)
# Episode 3, Step 19
# Random action
# WRONG   - Guess: 3>70. History: deque([11, 86, 3], maxlen=3)
# History: deque([86, 3, 69], maxlen=3)
# Episode 3, Step 20
# Random action
# CORRECT - Guess: 69<=70. History: deque([86, 3, 69], maxlen=3)
# History: deque([3, 69, 15], maxlen=3)
# Episode 3, Step 21
# Random action
# WRONG   - Guess: 15>70. History: deque([3, 69, 15], maxlen=3)
# History: deque([69, 15, 77], maxlen=3)
# Episode 3, Step 22
# Random action
# WRONG   - Guess: 77<=70. History: deque([69, 15, 77], maxlen=3)
# History: deque([15, 77, 11], maxlen=3)
# Episode 3, Step 23
# Random action
# CORRECT - Guess: 11<=70. History: deque([15, 77, 11], maxlen=3)
# History: deque([77, 11, 97], maxlen=3)
# Episode 3, Step 24
# Random action
# CORRECT - Guess: 97>70. History: deque([77, 11, 97], maxlen=3)
# History: deque([11, 97, 49], maxlen=3)
# Episode 3, Step 25
# Random action
# CORRECT - Guess: 49<=70. History: deque([11, 97, 49], maxlen=3)
# History: deque([97, 49, 37], maxlen=3)
# Episode 3, Step 26
# Random action
# WRONG   - Guess: 37>70. History: deque([97, 49, 37], maxlen=3)
# History: deque([49, 37, 94], maxlen=3)
# Episode 3, Step 27
# Random action
# WRONG   - Guess: 94<=70. History: deque([49, 37, 94], maxlen=3)
# History: deque([37, 94, 80], maxlen=3)
# Episode 3, Step 28
# Random action
# WRONG   - Guess: 80<=70. History: deque([37, 94, 80], maxlen=3)
# History: deque([94, 80, 20], maxlen=3)
# Episode 3, Step 29
# Random action
# CORRECT - Guess: 20<=70. History: deque([94, 80, 20], maxlen=3)
# History: deque([80, 20, 49], maxlen=3)
# Episode 3, Step 30
# Random action
# CORRECT - Guess: 49<=70. History: deque([80, 20, 49], maxlen=3)
# History: deque([20, 49, 6], maxlen=3)
# Episode 3, Step 31
# Random action
# WRONG   - Guess: 6>70. History: deque([20, 49, 6], maxlen=3)
# History: deque([49, 6, 8], maxlen=3)
# Episode 3, Step 32
# Random action
# CORRECT - Guess: 8<=70. History: deque([49, 6, 8], maxlen=3)
# History: deque([6, 8, 77], maxlen=3)
# Episode 3, Step 33
# Random action
# CORRECT - Guess: 77>70. History: deque([6, 8, 77], maxlen=3)
# History: deque([8, 77, 23], maxlen=3)
# Episode 3, Step 34
# Random action
# WRONG   - Guess: 23>70. History: deque([8, 77, 23], maxlen=3)
# History: deque([77, 23, 64], maxlen=3)
# Episode 3, Step 35
# Random action
# CORRECT - Guess: 64<=70. History: deque([77, 23, 64], maxlen=3)
# History: deque([23, 64, 25], maxlen=3)
# Episode 3, Step 36
# Random action
# CORRECT - Guess: 25<=70. History: deque([23, 64, 25], maxlen=3)
# History: deque([64, 25, 70], maxlen=3)
# Episode 3, Step 37
# Random action
# CORRECT - Guess: 70<=70. History: deque([64, 25, 70], maxlen=3)
# History: deque([25, 70, 53], maxlen=3)
# Episode 3, Step 38
# Random action
# WRONG   - Guess: 53>70. History: deque([25, 70, 53], maxlen=3)
# History: deque([70, 53, 5], maxlen=3)
# Episode 3, Step 39
# Random action
# WRONG   - Guess: 5>70. History: deque([70, 53, 5], maxlen=3)
# History: deque([53, 5, 77], maxlen=3)
# Episode 3, Step 40
# Random action
# CORRECT - Guess: 77>70. History: deque([53, 5, 77], maxlen=3)
# History: deque([5, 77, 57], maxlen=3)
# Episode 3, Step 41
# Random action
# WRONG   - Guess: 57>70. History: deque([5, 77, 57], maxlen=3)
# History: deque([77, 57, 82], maxlen=3)
# Episode 3, Step 42
# Random action
# WRONG   - Guess: 82<=70. History: deque([77, 57, 82], maxlen=3)
# History: deque([57, 82, 48], maxlen=3)
# Episode 3, Step 43
# Random action
# CORRECT - Guess: 48<=70. History: deque([57, 82, 48], maxlen=3)
# History: deque([82, 48, 51], maxlen=3)
# Episode 3, Step 44
# Random action
# CORRECT - Guess: 51<=70. History: deque([82, 48, 51], maxlen=3)
# History: deque([48, 51, 55], maxlen=3)
# Episode 3, Step 45
# Random action
# WRONG   - Guess: 55>70. History: deque([48, 51, 55], maxlen=3)
# History: deque([51, 55, 34], maxlen=3)
# Episode 3, Step 46
# Random action
# WRONG   - Guess: 34>70. History: deque([51, 55, 34], maxlen=3)
# History: deque([55, 34, 4], maxlen=3)
# Episode 3, Step 47
# Random action
# WRONG   - Guess: 4>70. History: deque([55, 34, 4], maxlen=3)
# History: deque([34, 4, 84], maxlen=3)
# Episode 3, Step 48
# Random action
# CORRECT - Guess: 84>70. History: deque([34, 4, 84], maxlen=3)
# History: deque([4, 84, 75], maxlen=3)
# Episode 3, Step 49
# Random action
# WRONG   - Guess: 75<=70. History: deque([4, 84, 75], maxlen=3)
# History: deque([84, 75, 70], maxlen=3)
# Agent memory: 200
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 0.1251 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 15.4767 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 1.2184 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 2.3801 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 0.3783 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 21.2868 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 10.4928 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 13.8254 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 1.2335 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 1.0561 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 26.0403 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 0.0160 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.1770 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 65.5173 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 32.9574 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 29.4391 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 11.2032 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 42.3316 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 - 0s - loss: 1.2273 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 - 0s - loss: 5.8906 - 10ms/epoch - 10ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 0.2188 - 15ms/epoch - 15ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 54.4868 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 15.4949 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 1.5456 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 - 0s - loss: 0.6023 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 5.0395 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 - 0s - loss: 4.0294 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 - 0s - loss: 8.2485 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 13.8943 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 0.0666 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 - 0s - loss: 9.1663 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 30.2313 - 4ms/epoch - 4ms/step
# Episode 4, Step 0
# Random action
# WRONG   - Guess: 97<=70. History: deque([93, 77, 97], maxlen=3)
# History: deque([77, 97, 59], maxlen=3)
# Episode 4, Step 1
# Random action
# CORRECT - Guess: 59<=70. History: deque([77, 97, 59], maxlen=3)
# History: deque([97, 59, 92], maxlen=3)
# Episode 4, Step 2
# Random action
# CORRECT - Guess: 92>70. History: deque([97, 59, 92], maxlen=3)
# History: deque([59, 92, 95], maxlen=3)
# Episode 4, Step 3
# Random action
# WRONG   - Guess: 95<=70. History: deque([59, 92, 95], maxlen=3)
# History: deque([92, 95, 15], maxlen=3)
# Episode 4, Step 4
# Random action
# WRONG   - Guess: 15>70. History: deque([92, 95, 15], maxlen=3)
# History: deque([95, 15, 92], maxlen=3)
# Episode 4, Step 5
# Random action
# WRONG   - Guess: 92<=70. History: deque([95, 15, 92], maxlen=3)
# History: deque([15, 92, 61], maxlen=3)
# Episode 4, Step 6
# Random action
# WRONG   - Guess: 61>70. History: deque([15, 92, 61], maxlen=3)
# History: deque([92, 61, 49], maxlen=3)
# Episode 4, Step 7
# Random action
# WRONG   - Guess: 49>70. History: deque([92, 61, 49], maxlen=3)
# History: deque([61, 49, 69], maxlen=3)
# Episode 4, Step 8
# Random action
# CORRECT - Guess: 69<=70. History: deque([61, 49, 69], maxlen=3)
# History: deque([49, 69, 15], maxlen=3)
# Episode 4, Step 9
# Random action
# ...
# 1/1 - 0s - loss: 0.6744 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 - 0s - loss: 0.1038 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 12.9832 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 65.5390 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 0.3827 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 - 0s - loss: 0.4526 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.0151 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.0057 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 34.4786 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 - 0s - loss: 0.3373 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.0924 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 - 0s - loss: 3.1405 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 1.8230 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 5.9178 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 9.0063e-04 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 - 0s - loss: 1.2741 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 - 0s - loss: 1.5607 - 13ms/epoch - 13ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 1.2483 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.0175 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 0.1289 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 1.4397 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 1.4421 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.6463 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 1.5218 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 1.5951 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 - 0s - loss: 17.1282 - 7ms/epoch - 7ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 - 0s - loss: 18.5350 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 - 0s - loss: 1.5574 - 8ms/epoch - 8ms/step
# Episode 9, Step 0
# Random action
# CORRECT - Guess: 69<=70. History: deque([47, 39, 69], maxlen=3)
# History: deque([39, 69, 86], maxlen=3)
# Episode 9, Step 1
# Random action
# CORRECT - Guess: 86>70. History: deque([39, 69, 86], maxlen=3)
# History: deque([69, 86, 20], maxlen=3)
# Episode 9, Step 2
# Random action
# CORRECT - Guess: 20<=70. History: deque([69, 86, 20], maxlen=3)
# History: deque([86, 20, 24], maxlen=3)
# Episode 9, Step 3
# Random action
# CORRECT - Guess: 24<=70. History: deque([86, 20, 24], maxlen=3)
# History: deque([20, 24, 82], maxlen=3)
# Episode 9, Step 4
# Random action
# WRONG   - Guess: 82<=70. History: deque([20, 24, 82], maxlen=3)
# History: deque([24, 82, 88], maxlen=3)
# Episode 9, Step 5
# Random action
# CORRECT - Guess: 88>70. History: deque([24, 82, 88], maxlen=3)
# History: deque([82, 88, 35], maxlen=3)
# Episode 9, Step 6
# Random action
# CORRECT - Guess: 35<=70. History: deque([82, 88, 35], maxlen=3)
# History: deque([88, 35, 50], maxlen=3)
# Episode 9, Step 7
# Random action
# WRONG   - Guess: 50>70. History: deque([88, 35, 50], maxlen=3)
# History: deque([35, 50, 47], maxlen=3)
# Episode 9, Step 8
# Random action
# CORRECT - Guess: 47<=70. History: deque([35, 50, 47], maxlen=3)
# History: deque([50, 47, 67], maxlen=3)
# Episode 9, Step 9
# Predicting action
# 1/1 [==============================] - 0s 34ms/step
# CORRECT - Guess: 67<=70. History: deque([50, 47, 67], maxlen=3)
# History: deque([47, 67, 89], maxlen=3)
# Episode 9, Step 10
# Random action
# WRONG   - Guess: 89<=70. History: deque([47, 67, 89], maxlen=3)
# History: deque([67, 89, 59], maxlen=3)
# Episode 9, Step 11
# Random action
# WRONG   - Guess: 59>70. History: deque([67, 89, 59], maxlen=3)
# History: deque([89, 59, 30], maxlen=3)
# Episode 9, Step 12
# Random action
# CORRECT - Guess: 30<=70. History: deque([89, 59, 30], maxlen=3)
# History: deque([59, 30, 11], maxlen=3)
# Episode 9, Step 13
# Random action
# WRONG   - Guess: 11>70. History: deque([59, 30, 11], maxlen=3)
# History: deque([30, 11, 42], maxlen=3)
# Episode 9, Step 14
# Random action
# CORRECT - Guess: 42<=70. History: deque([30, 11, 42], maxlen=3)
# History: deque([11, 42, 20], maxlen=3)
# Episode 9, Step 15
# Random action
# WRONG   - Guess: 20>70. History: deque([11, 42, 20], maxlen=3)
# History: deque([42, 20, 40], maxlen=3)
# Episode 9, Step 16
# Random action
# WRONG   - Guess: 40>70. History: deque([42, 20, 40], maxlen=3)
# History: deque([20, 40, 39], maxlen=3)
# Episode 9, Step 17
# Random action
# CORRECT - Guess: 39<=70. History: deque([20, 40, 39], maxlen=3)
# History: deque([40, 39, 9], maxlen=3)
# Episode 9, Step 18
# Random action
# CORRECT - Guess: 9<=70. History: deque([40, 39, 9], maxlen=3)
# History: deque([39, 9, 82], maxlen=3)
# Episode 9, Step 19
# Random action
# CORRECT - Guess: 82>70. History: deque([39, 9, 82], maxlen=3)
# History: deque([9, 82, 38], maxlen=3)
# Episode 9, Step 20
# Random action
# WRONG   - Guess: 38>70. History: deque([9, 82, 38], maxlen=3)
# History: deque([82, 38, 86], maxlen=3)
# Episode 9, Step 21
# Random action
# CORRECT - Guess: 86>70. History: deque([82, 38, 86], maxlen=3)
# History: deque([38, 86, 94], maxlen=3)
# Episode 9, Step 22
# Random action
# WRONG   - Guess: 94<=70. History: deque([38, 86, 94], maxlen=3)
# History: deque([86, 94, 94], maxlen=3)
# Episode 9, Step 23
# Random action
# CORRECT - Guess: 94>70. History: deque([86, 94, 94], maxlen=3)
# History: deque([94, 94, 72], maxlen=3)
# Episode 9, Step 24
# Random action
# WRONG   - Guess: 72<=70. History: deque([94, 94, 72], maxlen=3)
# History: deque([94, 72, 38], maxlen=3)
# Episode 9, Step 25
# Random action
# CORRECT - Guess: 38<=70. History: deque([94, 72, 38], maxlen=3)
# History: deque([72, 38, 43], maxlen=3)
# Episode 9, Step 26
# Random action
# CORRECT - Guess: 43<=70. History: deque([72, 38, 43], maxlen=3)
# History: deque([38, 43, 75], maxlen=3)
# Episode 9, Step 27
# Random action
# WRONG   - Guess: 75<=70. History: deque([38, 43, 75], maxlen=3)
# History: deque([43, 75, 19], maxlen=3)
# Episode 9, Step 28
# Random action
# WRONG   - Guess: 19>70. History: deque([43, 75, 19], maxlen=3)
# History: deque([75, 19, 40], maxlen=3)
# Episode 9, Step 29
# Random action
# CORRECT - Guess: 40<=70. History: deque([75, 19, 40], maxlen=3)
# History: deque([19, 40, 72], maxlen=3)
# Episode 9, Step 30
# Random action
# WRONG   - Guess: 72<=70. History: deque([19, 40, 72], maxlen=3)
# History: deque([40, 72, 55], maxlen=3)
# Episode 9, Step 31
# Random action
# WRONG   - Guess: 55>70. History: deque([40, 72, 55], maxlen=3)
# History: deque([72, 55, 32], maxlen=3)
# Episode 9, Step 32
# Random action
# CORRECT - Guess: 32<=70. History: deque([72, 55, 32], maxlen=3)
# History: deque([55, 32, 54], maxlen=3)
# Episode 9, Step 33
# Random action
# WRONG   - Guess: 54>70. History: deque([55, 32, 54], maxlen=3)
# History: deque([32, 54, 17], maxlen=3)
# Episode 9, Step 34
# Random action
# CORRECT - Guess: 17<=70. History: deque([32, 54, 17], maxlen=3)
# History: deque([54, 17, 98], maxlen=3)
# Episode 9, Step 35
# Random action
# WRONG   - Guess: 98<=70. History: deque([54, 17, 98], maxlen=3)
# History: deque([17, 98, 8], maxlen=3)
# Episode 9, Step 36
# Random action
# CORRECT - Guess: 8<=70. History: deque([17, 98, 8], maxlen=3)
# History: deque([98, 8, 17], maxlen=3)
# Episode 9, Step 37
# Random action
# CORRECT - Guess: 17<=70. History: deque([98, 8, 17], maxlen=3)
# History: deque([8, 17, 6], maxlen=3)
# Episode 9, Step 38
# Random action
# CORRECT - Guess: 6<=70. History: deque([8, 17, 6], maxlen=3)
# History: deque([17, 6, 10], maxlen=3)
# Episode 9, Step 39
# Random action
# WRONG   - Guess: 10>70. History: deque([17, 6, 10], maxlen=3)
# History: deque([6, 10, 30], maxlen=3)
# Episode 9, Step 40
# Random action
# CORRECT - Guess: 30<=70. History: deque([6, 10, 30], maxlen=3)
# History: deque([10, 30, 19], maxlen=3)
# Episode 9, Step 41
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# CORRECT - Guess: 19<=70. History: deque([10, 30, 19], maxlen=3)
# History: deque([30, 19, 10], maxlen=3)
# Episode 9, Step 42
# Random action
# WRONG   - Guess: 10>70. History: deque([30, 19, 10], maxlen=3)
# History: deque([19, 10, 27], maxlen=3)
# Episode 9, Step 43
# Random action
# WRONG   - Guess: 27>70. History: deque([19, 10, 27], maxlen=3)
# History: deque([10, 27, 31], maxlen=3)
# Episode 9, Step 44
# Random action
# WRONG   - Guess: 31>70. History: deque([10, 27, 31], maxlen=3)
# History: deque([27, 31, 14], maxlen=3)
# Episode 9, Step 45
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# CORRECT - Guess: 14<=70. History: deque([27, 31, 14], maxlen=3)
# History: deque([31, 14, 45], maxlen=3)
# Episode 9, Step 46
# Random action
# WRONG   - Guess: 45>70. History: deque([31, 14, 45], maxlen=3)
# History: deque([14, 45, 2], maxlen=3)
# Episode 9, Step 47
# Random action
# WRONG   - Guess: 2>70. History: deque([14, 45, 2], maxlen=3)
# History: deque([45, 2, 11], maxlen=3)
# Episode 9, Step 48
# Random action
# CORRECT - Guess: 11<=70. History: deque([45, 2, 11], maxlen=3)
# History: deque([2, 11, 24], maxlen=3)
# Episode 9, Step 49
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# WRONG   - Guess: 24>70. History: deque([2, 11, 24], maxlen=3)
# History: deque([11, 24, 30], maxlen=3)
# Agent memory: 500
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 - 0s - loss: 5.8542 - 8ms/epoch - 8ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 1.0282 - 6ms/epoch - 6ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 - 0s - loss: 0.0030 - 8ms/epoch - 8ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 - 0s - loss: 0.9387 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 - 0s - loss: 1.8186 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 - 0s - loss: 0.0051 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 1.2602 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 2.3851 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 34.1973 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 1.2493 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 0.4187 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 0.9442 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 - 0s - loss: 10.6413 - 8ms/epoch - 8ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 1.1895 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 5.4705e-05 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 0.0924 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 1.4418 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 - 0s - loss: 0.1749 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 0.0028 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 0.2289 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 7.9602 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 - 0s - loss: 0.0076 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 11.1399 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 0.9407 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 8.8527 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 1.3944 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 6.5526 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 - 0s - loss: 10.9411 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 - 0s - loss: 4.7485 - 4ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 - 0s - loss: 6.9458 - 5ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 - 0s - loss: 17.7968 - 3ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 - 0s - loss: 11.3000 - 4ms/epoch - 4ms/step

# %%
prev_epsilon = agent.epsilon
agent.epsilon = 0.0

def predict(agent, state):
    state = np.reshape(state, [1, history_size])
    action = agent.act(state)
    return action

history = deque([np.random.randint(0, 100) for _ in range(history_size)], maxlen=history_size)
current_number = history[-1]

correct = 0
incorrect = 0

# For Real Loop
for e in range(100):
    prediction = predict(agent, np.array(history))

    guess = ""
    if prediction == 1:
        guess = ">"
    else:
        guess = "<="

    # Determine if the prediction was correct
    if (prediction == 1 and current_number > CHOSEN_X) or (prediction == 0 and current_number <= CHOSEN_X):
        correct += 1
        print(f"CORRECT - Guess: {current_number}{guess}{CHOSEN_X}. History: {history}")
        reward = 1
    else:
        incorrect += 1
        print(f"WRONG   - Guess: {current_number}{guess}{CHOSEN_X}. History: {history}")
        reward = -1

    # Generate a new number and update history
    current_number = np.random.randint(0, 100)
    history.append(current_number)

print(f"Correct: {correct}, Incorrect: {incorrect}")


print(f"Agent History: {len(agent.memory)}")
# Out:
# Predicting action
# 1/1 [==============================] - 0s 145ms/step
# CORRECT - Guess: 99>70. History: deque([8, 76, 99], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# WRONG   - Guess: 90<=70. History: deque([76, 99, 90], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 51ms/step
# WRONG   - Guess: 80<=70. History: deque([99, 90, 80], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 20ms/step
# CORRECT - Guess: 54<=70. History: deque([90, 80, 54], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 17ms/step
# CORRECT - Guess: 86>70. History: deque([80, 54, 86], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 17ms/step
# CORRECT - Guess: 19<=70. History: deque([54, 86, 19], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 17ms/step
# CORRECT - Guess: 67<=70. History: deque([86, 19, 67], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# WRONG   - Guess: 44>70. History: deque([19, 67, 44], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 23ms/step
# WRONG   - Guess: 65>70. History: deque([67, 44, 65], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 151ms/step
# CORRECT - Guess: 28<=70. History: deque([44, 65, 28], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 133ms/step
# WRONG   - Guess: 66>70. History: deque([65, 28, 66], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 76ms/step
# CORRECT - Guess: 41<=70. History: deque([28, 66, 41], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 19ms/step
# WRONG   - Guess: 24>70. History: deque([66, 41, 24], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# WRONG   - Guess: 58>70. History: deque([41, 24, 58], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 37ms/step
# WRONG   - Guess: 22>70. History: deque([24, 58, 22], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 27ms/step
# CORRECT - Guess: 80>70. History: deque([58, 22, 80], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 30ms/step
# WRONG   - Guess: 73<=70. History: deque([22, 80, 73], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# CORRECT - Guess: 68<=70. History: deque([80, 73, 68], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 30ms/step
# CORRECT - Guess: 65<=70. History: deque([73, 68, 65], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# WRONG   - Guess: 86<=70. History: deque([68, 65, 86], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 27ms/step
# CORRECT - Guess: 7<=70. History: deque([65, 86, 7], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 26ms/step
# CORRECT - Guess: 52<=70. History: deque([86, 7, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# WRONG   - Guess: 63>70. History: deque([7, 52, 63], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 30ms/step
# WRONG   - Guess: 82<=70. History: deque([52, 63, 82], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 38ms/step
# CORRECT - Guess: 4<=70. History: deque([63, 82, 4], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 43ms/step
# CORRECT - Guess: 35<=70. History: deque([82, 4, 35], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 30ms/step
# WRONG   - Guess: 41>70. History: deque([4, 35, 41], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# CORRECT - Guess: 15<=70. History: deque([35, 41, 15], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 37ms/step
# WRONG   - Guess: 62>70. History: deque([41, 15, 62], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# WRONG   - Guess: 21>70. History: deque([15, 62, 21], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# CORRECT - Guess: 78>70. History: deque([62, 21, 78], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# CORRECT - Guess: 95>70. History: deque([21, 78, 95], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# WRONG   - Guess: 81<=70. History: deque([78, 95, 81], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 34ms/step
# CORRECT - Guess: 98>70. History: deque([95, 81, 98], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 32ms/step
# CORRECT - Guess: 38<=70. History: deque([81, 98, 38], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 42ms/step
# CORRECT - Guess: 2<=70. History: deque([98, 38, 2], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# CORRECT - Guess: 3<=70. History: deque([38, 2, 3], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 30ms/step
# CORRECT - Guess: 52<=70. History: deque([2, 3, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 36ms/step
# CORRECT - Guess: 52<=70. History: deque([3, 52, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 52<=70. History: deque([52, 52, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 67<=70. History: deque([52, 52, 67], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 21ms/step
# CORRECT - Guess: 13<=70. History: deque([52, 67, 13], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 76>70. History: deque([67, 13, 76], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# WRONG   - Guess: 13>70. History: deque([13, 76, 13], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 23ms/step
# CORRECT - Guess: 95>70. History: deque([76, 13, 95], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 24ms/step
# WRONG   - Guess: 62>70. History: deque([13, 95, 62], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 23ms/step
# WRONG   - Guess: 7>70. History: deque([95, 62, 7], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 12<=70. History: deque([62, 7, 12], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 4<=70. History: deque([7, 12, 4], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 21ms/step
# CORRECT - Guess: 3<=70. History: deque([12, 4, 3], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 20ms/step
# WRONG   - Guess: 94<=70. History: deque([4, 3, 94], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# CORRECT - Guess: 76>70. History: deque([3, 94, 76], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 19ms/step
# WRONG   - Guess: 30>70. History: deque([94, 76, 30], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# WRONG   - Guess: 33>70. History: deque([76, 30, 33], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 86>70. History: deque([30, 33, 86], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 19ms/step
# WRONG   - Guess: 8>70. History: deque([33, 86, 8], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 22ms/step
# CORRECT - Guess: 18<=70. History: deque([86, 8, 18], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 30ms/step
# WRONG   - Guess: 2>70. History: deque([8, 18, 2], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 25ms/step
# CORRECT - Guess: 74>70. History: deque([18, 2, 74], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 23ms/step
# WRONG   - Guess: 4>70. History: deque([2, 74, 4], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 21ms/step
# CORRECT - Guess: 41<=70. History: deque([74, 4, 41], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 22ms/step
# WRONG   - Guess: 4>70. History: deque([4, 41, 4], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 13<=70. History: deque([41, 4, 13], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 24ms/step
# CORRECT - Guess: 12<=70. History: deque([4, 13, 12], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 23ms/step
# WRONG   - Guess: 42>70. History: deque([13, 12, 42], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 32ms/step
# CORRECT - Guess: 25<=70. History: deque([12, 42, 25], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 26<=70. History: deque([42, 25, 26], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 29<=70. History: deque([25, 26, 29], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 95>70. History: deque([26, 29, 95], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# WRONG   - Guess: 34>70. History: deque([29, 95, 34], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# CORRECT - Guess: 31<=70. History: deque([95, 34, 31], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 36ms/step
# WRONG   - Guess: 5>70. History: deque([34, 31, 5], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 35ms/step
# CORRECT - Guess: 18<=70. History: deque([31, 5, 18], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 37ms/step
# WRONG   - Guess: 40>70. History: deque([5, 18, 40], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 26ms/step
# CORRECT - Guess: 42<=70. History: deque([18, 40, 42], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 26ms/step
# CORRECT - Guess: 46<=70. History: deque([40, 42, 46], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 27ms/step
# CORRECT - Guess: 65<=70. History: deque([42, 46, 65], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# CORRECT - Guess: 56<=70. History: deque([46, 65, 56], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# WRONG   - Guess: 9>70. History: deque([65, 56, 9], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 27ms/step
# CORRECT - Guess: 26<=70. History: deque([56, 9, 26], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 39ms/step
# CORRECT - Guess: 89>70. History: deque([9, 26, 89], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 28ms/step
# WRONG   - Guess: 26>70. History: deque([26, 89, 26], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 32ms/step
# CORRECT - Guess: 19<=70. History: deque([89, 26, 19], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 37ms/step
# WRONG   - Guess: 52>70. History: deque([26, 19, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 41ms/step
# CORRECT - Guess: 52<=70. History: deque([19, 52, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# CORRECT - Guess: 17<=70. History: deque([52, 52, 17], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 34ms/step
# CORRECT - Guess: 97>70. History: deque([52, 17, 97], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# WRONG   - Guess: 11>70. History: deque([17, 97, 11], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 31ms/step
# WRONG   - Guess: 79<=70. History: deque([97, 11, 79], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 32ms/step
# WRONG   - Guess: 58>70. History: deque([11, 79, 58], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 29ms/step
# CORRECT - Guess: 52<=70. History: deque([79, 58, 52], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 32ms/step
# CORRECT - Guess: 88>70. History: deque([58, 52, 88], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 34ms/step
# WRONG   - Guess: 74<=70. History: deque([52, 88, 74], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 17ms/step
# WRONG   - Guess: 28>70. History: deque([88, 74, 28], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# CORRECT - Guess: 66<=70. History: deque([74, 28, 66], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 21ms/step
# CORRECT - Guess: 65<=70. History: deque([28, 66, 65], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 27ms/step
# CORRECT - Guess: 8<=70. History: deque([66, 65, 8], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 23ms/step
# CORRECT - Guess: 73>70. History: deque([65, 8, 73], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 18ms/step
# WRONG   - Guess: 76<=70. History: deque([8, 73, 76], maxlen=3)
# Predicting action
# 1/1 [==============================] - 0s 17ms/step
# CORRECT - Guess: 58<=70. History: deque([73, 76, 58], maxlen=3)
# Correct: 61, Incorrect: 39
# Agent History: 500
